# %%
import json
import requests
import pandas as pd
from pymongo import MongoClient
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.widgets.text("PastaDataLake",'THIAGO_TESTE_Synapse/Stack')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
PastaDataLake = dbutils.widgets.get('PastaDataLake')

#print(PastaDataLake)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ###SETAR AS VARIAVEIS e o caminho

# %%
CaminhoLandinzone = f'/mnt/landingzone/{PastaDataLake}'

#f'/mnt/landingzone/{Path}'
print(CaminhoLandinzone )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/landingzone/THIAGO_TESTE_Synapse/Stack
# </div>

# %%
arquivoJson = spark.read.load(CaminhoLandinzone, format='json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pandas=arquivoJson.toPandas()
display(df_pandas)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>_index</th><th>_score</th><th>_source.@timestamp</th><th>_source.@version</th><th>_source.co_condicao_maternal</th><th>_source.data_importacao_datalake</th><th>_source.data_importacao_rnds</th><th>_source.document_id</th><th>_source.ds_condicao_maternal</th><th>_source.dt_deleted</th><th>_source.estabelecimento_municipio_codigo</th><th>_source.estabelecimento_municipio_nome</th><th>_source.estabelecimento_razaoSocial</th><th>_source.estabelecimento_uf</th><th>_source.estabelecimento_valor</th><th>_source.estalecimento_noFantasia</th><th>_source.id_sistema_origem</th><th>_source.paciente_dataNascimento</th><th>_source.paciente_endereco_cep</th><th>_source.paciente_endereco_coIbgeMunicipio</th><th>_source.paciente_endereco_coPais</th><th>_source.paciente_endereco_nmMunicipio</th><th>_source.paciente_endereco_nmPais</th><th>_source.paciente_endereco_uf</th><th>_source.paciente_enumSexoBiologico</th><th>_source.paciente_id</th><th>_source.paciente_idade</th><th>_source.paciente_nacionalidade_enumNacionalidade</th><th>_source.paciente_racaCor_codigo</th><th>_source.paciente_racaCor_valor</th><th>_source.sistema_origem</th><th>_source.status</th><th>_source.vacina_categoria_codigo</th><th>_source.vacina_categoria_nome</th><th>_source.vacina_codigo</th><th>_source.vacina_dataAplicacao</th><th>_source.vacina_descricao_dose</th><th>_source.vacina_fabricante_nome</th><th>_source.vacina_fabricante_referencia</th><th>_source.vacina_grupoAtendimento_codigo</th><th>_source.vacina_grupoAtendimento_nome</th><th>_source.vacina_lote</th><th>_source.vacina_nome</th><th>_source.vacina_numDose</th><th>_type</th></tr></thead><tbody><tr><td>0c9fa849-34c7-4c44-a5b1-f94c15d5354c-i0b0</td><td>desc-imunizacao-v5</td><td>1.0</td><td>2023-01-17T21:16:25.655Z</td><td>1</td><td>null</td><td>2023-01-17T18:06:20.000Z</td><td>2023-01-17T15:55:39.000Z</td><td>0c9fa849-34c7-4c44-a5b1-f94c15d5354c-i0b0</td><td>null</td><td>null</td><td>351380</td><td>DIADEMA</td><td>PREFEITURA DO MUNICIPIO DE DIADEMA</td><td>SP</td><td>2801094</td><td>UBS CENTRO</td><td>18262</td><td>2004-05-12</td><td>09910</td><td>351380</td><td>10</td><td>DIADEMA</td><td>BRASIL</td><td>SP</td><td>F</td><td>4bf8569dd9885cb6fac77f8e1012052c9f15583a03b56f6dd3add2ed6b884e62</td><td>18</td><td>B</td><td>99</td><td>SEM INFORMACAO</td><td>VACIVIDA</td><td>final</td><td>2</td><td>Faixa Etária</td><td>86</td><td>2023-01-17T00:00:00.000Z</td><td>2º Reforço</td><td>SINOVAC/BUTANTAN</td><td>null</td><td>000206</td><td>Pessoas de 12 a 17 anos</td><td>220252</td><td>COVID-19 SINOVAC/BUTANTAN - CORONAVAC</td><td>7</td><td>_doc</td></tr><tr><td>f2588a1c-14e6-4dbf-ad91-788fd40dcf74-i0b0</td><td>desc-imunizacao-v5</td><td>1.0</td><td>2023-01-17T21:16:25.657Z</td><td>1</td><td>null</td><td>2023-01-17T18:06:20.000Z</td><td>2023-01-17T13:24:21.000Z</td><td>f2588a1c-14e6-4dbf-ad91-788fd40dcf74-i0b0</td><td>null</td><td>null</td><td>353870</td><td>PIRACICABA</td><td>PREFEITURA MUNICIPAL DE PIRACICABA</td><td>SP</td><td>2060000</td><td>UNIDADE BASICA DE SAUDE VILA INDEPENDENCIA PIRACICABA</td><td>18262</td><td>1973-04-22</td><td>17012</td><td>350600</td><td>10</td><td>BAURU</td><td>BRASIL</td><td>SP</td><td>M</td><td>3f7fe4b50e4b066bca95f121f674a963ec59dce0462d520b6832dc353c3d181c</td><td>49</td><td>B</td><td>99</td><td>SEM INFORMACAO</td><td>VACIVIDA</td><td>final</td><td>2</td><td>Faixa Etária</td><td>87</td><td>2023-01-17T00:00:00.000Z</td><td>2º Reforço</td><td>PFIZER</td><td>null</td><td>000201</td><td>Pessoas de 18 a 64 anos</td><td>FX1188</td><td>COVID-19 PFIZER - COMIRNATY</td><td>7</td><td>_doc</td></tr><tr><td>6eb3a728-18ea-455c-9ba1-81f22d2eeb30-i0b0</td><td>desc-imunizacao-v5</td><td>1.0</td><td>2023-01-17T21:16:25.659Z</td><td>1</td><td>1.0</td><td>2023-01-17T18:06:20.000Z</td><td>2023-01-17T12:16:59.000Z</td><td>6eb3a728-18ea-455c-9ba1-81f22d2eeb30-i0b0</td><td>Nenhuma</td>< ...

# %%
df_pandasColunasEscolhidas = df_pandas[['_source.paciente_idade','_source.estabelecimento_municipio_nome','_source.vacina_dataAplicacao','_source.vacina_categoria_nome','_source.estabelecimento_uf','_source.paciente_enumSexoBiologico','_source.paciente_racaCor_valor','_source.vacina_fabricante_nome','_source.estabelecimento_razaoSocial','_source.vacina_descricao_dose']]
              
df_spark=spark.createDataFrame(df_pandasColunasEscolhidas)

df_spark=df_spark.withColumnRenamed('_source.paciente_idade','PacienteIdade').withColumnRenamed('_source.estabelecimento_municipio_nome','NomeMunicipio')\
.withColumnRenamed('_source.vacina_dataAplicacao', 'DataAplicacao')\
.withColumnRenamed('_source.vacina_categoria_nome','CategoriaVacina')\
.withColumnRenamed('_source.estabelecimento_uf','UFdoEstabelecimento')\
.withColumnRenamed('_source.paciente_enumSexoBiologico','Sexo')\
.withColumnRenamed('_source.paciente_racaCor_valor','Cor')\
.withColumnRenamed('_source.vacina_fabricante_nome','FabricanteVacina')\
.withColumnRenamed('_source.estabelecimento_razaoSocial','RazaoSocialEstabelecimento')\
.withColumnRenamed('_source.vacina_descricao_dose','TipoDose')

display(df_spark)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
td><td>F</td><td>PARDA</td><td>PFIZER</td><td>PREFEITURA MUNICIPAL DE ITAPIUNA</td><td>2º Reforço</td></tr><tr><td>26</td><td>ICATU</td><td>2023-01-10T00:00:00.000Z</td><td>Povos e Comunidades Tradicionais</td><td>MA</td><td>M</td><td>AMARELA</td><td>PFIZER</td><td>MUNICIPIO DE ICATU</td><td>2º Reforço</td></tr><tr><td>66</td><td>CONDE</td><td>2022-12-21T00:00:00.000Z</td><td>Faixa Etária</td><td>BA</td><td>F</td><td>PARDA</td><td>ASTRAZENECA/FIOCRUZ</td><td>MUNICIPIO DE CONDE</td><td>2º Reforço</td></tr><tr><td>35</td><td>CUMARU</td><td>2022-12-14T00:00:00.000Z</td><td>Faixa Etária</td><td>PE</td><td>F</td><td>AMARELA</td><td>JANSSEN</td><td>PREFEITURA MUNICIPAL DE CUMARU</td><td>2º Reforço</td></tr><tr><td>28</td><td>IBIRATAIA</td><td>2023-01-17T00:00:00.000Z</td><td>Faixa Etária</td><td>BA</td><td>F</td><td>PARDA</td><td>PFIZER</td><td>MUNICIPIO DE IBIRATAIA</td><td>2º Reforço</td></tr><tr><td>64</td><td>SAO JOSE DE MIPIBU</td><td>2023-01-10T00:00:00.000Z</td><td>Faixa Etária</td><td>RN</td><td>M</td><td>PARDA</td><td>ASTRAZENECA/FIOCRUZ</td><td>MUNICIPIO DE SAO JOSE DE MIPIBU</td><td>2º Reforço</td></tr><tr><td>56</td><td>GUARUJA</td><td>2023-01-17T00:00:00.000Z</td><td>Trabalhadores de Saúde</td><td>SP</td><td>F</td><td>BRANCA</td><td>PFIZER</td><td>MUNICIPIO DE GUARUJA</td><td>2º Reforço</td></tr><tr><td>47</td><td>BRASILIA</td><td>2023-01-17T00:00:00.000Z</td><td>Faixa Etária</td><td>DF</td><td>F</td><td>SEM INFORMACAO</td><td>ASTRAZENECA/FIOCRUZ</td><td>UNIDADE BASICA DE SAUDE N 02 DO RECANTO DAS EMAS</td><td>2º Reforço</td></tr><tr><td>69</td><td>CRUZEIRO</td><td>2023-01-06T00:00:00.000Z</td><td>Faixa Etária</td><td>SP</td><td>M</td><td>BRANCA</td><td>PFIZER</td><td>PREFEITURA MUNICIPAL DE CRUZEIRO</td><td>2º Reforço</td></tr><tr><td>27</td><td>BARRA DO CHOCA</td><td>2022-03-09T00:00:00.000Z</td><td>Faixa Etária</td ...

# %%
#display(df_spark)

df_spark_date = df_spark.withColumn('DataAplicacao',df_spark['DataAplicacao'].cast('date'))

display(df_spark_date)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PacienteIdade</th><th>NomeMunicipio</th><th>DataAplicacao</th><th>CategoriaVacina</th><th>UFdoEstabelecimento</th><th>Sexo</th><th>Cor</th><th>FabricanteVacina</th><th>RazaoSocialEstabelecimento</th><th>TipoDose</th></tr></thead><tbody><tr><td>18</td><td>DIADEMA</td><td>2023-01-17</td><td>Faixa Etária</td><td>SP</td><td>F</td><td>SEM INFORMACAO</td><td>SINOVAC/BUTANTAN</td><td>PREFEITURA DO MUNICIPIO DE DIADEMA</td><td>2º Reforço</td></tr><tr><td>49</td><td>PIRACICABA</td><td>2023-01-17</td><td>Faixa Etária</td><td>SP</td><td>M</td><td>SEM INFORMACAO</td><td>PFIZER</td><td>PREFEITURA MUNICIPAL D
td><td>PFIZER</td><td>PREFEITURA MUNICIPAL DE CRUZEIRO</td><td>2º Reforço</td></tr><tr><td>27</td><td>BARRA DO CHOCA</td><td>2022-03-09</td><td>Faixa Etária</td><td>BA</td><td>F</td><td>PARDA</td><td>PFIZER</td><td>PREFEITURA MUNICIPAL DE BARRA DO CHOCA</td><td>2ª Dose</td></tr><tr><td>5</td><td>GUARUJA</td><td>2023-01-17</td><td>null</td><td>SP</td><td>F</td><td>BRANCA</td><td>SINOVAC/BUTANTAN</td><td>MUNICI ...

# %%
#display(df_spark_date.summary())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_spark_date_SemNull = df_spark_date.filter(df_spark_date.CategoriaVacina.isNotNull())
df_spark_TotalmenteTratado = df_spark_date_SemNull.fillna(value='1ª Dose', subset=['TipoDose'])

#display(df_spark_date_SemNull2.summary())                 
display(df_spark_TotalmenteTratado)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PacienteIdade</th><th>NomeMunicipio</th><th>DataAplicacao</th><th>CategoriaVacina</th><th>UFdoEstabelecimento</th><th>Sexo</th><th>Cor</th><th>FabricanteVacina</th><th>RazaoSocialEstabelecimento</th><th>TipoDose</th></tr></thead><tbody><tr><td>18</td><td>DIADEMA</td><td>2023-01-17</td><td>Faixa Etária</td><td>SP</td><td>F</td><td>SEM INFORMACAO</td><td>SINOVAC/BUTANTAN</td><td>PREFEITURA DO MUNICIPIO DE DIADEMA</td><td>2º Reforço</td></tr><tr><td>49</td><td>PIRACICABA</td><td>2023-01-17</td><td>Faixa Etária</td><td>SP</td><td>M</td><td>SEM INFORMACAO</td><td>PFIZER</td><td>PREFEITURA MUNICIPAL DE PIRACICABA</td><td>2º Reforço</td></tr><tr><td>40</td><td>CARUARU</td><td>2023-01-17</td><td>Trabalhadores da Educação</td><td>PE</td><td>F</td><td>AMARELA</td><td>PFIZER</td><td>CENTRAL MUNICIPAL DE REDE DE FRIOS CMRF</td><td>2º Reforço</td></tr><tr><td>20</td><td>CAMETA</td><td>2022-10-26</td><td>Faixa Etária</td><td>PA</td><td>M</td><td>AMARELA</td><td>SINOVAC/BUTANTAN</td><td>PREFEITUTA MUNICIPAL DE CAMETA</td><td>2º Reforço</td></tr><tr><td>58</td><td>SAO PAULO</td><td>2023-01-17</td><td>Comorbidades</td><td>SP</td><td>F</td><td>PARDA</td><td>PFIZER</td><td>PREFEITURA DO MUNICIPIO DE SAO PAULO</td><td>2º Reforço</td></tr><tr><td>73</td><td>ARACAJU</td><td>2023-01-17</td><td>Faixa Etária</td><td>SE</td><td>M</td><td>SEM INFORMACAO</td><td>ASTRAZENECA/FIOCRUZ</td><td>SECRETARIA MUNICIPAL DE SAUDE DE ARACAJU</td><td>2º Reforço</td></tr><tr><td>33</td><td>SAO PAULO</td><td>2023-01-17</td><td>Faixa Etária</td><td>SP</td><td>F</td><td>SEM INFORMACAO</td><td>PFIZER</td><td>PREFEITURA DO MUNICIPIO DE SAO PAULO</td><td>2º Reforço</td></tr><tr><td>31</td><td>OCARA</td><td>2022-12-22</td><td>Faixa Etária</td><td>CE</td><td>F</td><td>PARDA</td><td>PFIZER</td><td>PREF M OCARA</td><td>2º Reforço</td></tr><tr><td>27</td><td>ITAPIUNA</td><td>2022-11-11</td><td>Faixa Etária</td><td>CE</td><td>F</td><td>PARDA</td><td>PFIZER</td><td>PREFEITURA MUNICIPAL DE ITAPIUNA</td><td>2º Reforço</td></tr><tr><td>26</td><td>ICATU</td><td>2023-01-10</td><td>Povos e Comunidades Tradicionais</td><td>MA</td><td>M</td><td>AMARELA</td><td>PFIZER</td><td>MUNICIPIO DE ICATU</td><td>2º Reforço</td></tr><tr><td>66</td><td>CONDE</td><td>2022-12-21</td><td>Faixa Etária</td><td>BA</td><td>F</td><td>PARDA</td><td>ASTRAZENECA/FIOCRUZ</td><td>MUNICIPIO DE CONDE</td><td>2º Reforço</td></tr><tr><td>35</td><td>CUMARU</td><td>2022-12-14</td><td>Faixa Etária</td><td>PE</td><td>F</td><td>AMARELA</td><td>JANSSEN</td><td>PREFEITURA MUNICIPAL DE CUMARU</td><td>2º Reforço</td></tr><tr><td>28</td><td>IBIRATAIA</td><td>2023-01-17</td><td>Faixa Etária</td><td>BA</td><td>F</td><td>PARDA</td><td>PFIZER</td><td>MUNICIPIO DE IBIRATAIA</td><td>2º Reforço</td></tr><tr><td>64</td><td>SAO JOSE DE MIPIBU</td><td>2023-01-10</td><td>Faixa Etária</td><td>RN</td><td>M</td><td>PARDA</td><td>ASTRAZENECA/FIOCRUZ</td><td>MUNICIPIO DE SAO JOSE DE MIPIBU</td><td>2º Reforço</td></tr><tr><td>56</td><td>GUARUJA</td><td>2023-01-17</td><td>Trabalhadores de Saúde</td><td>SP</td><td>F</td><td>BRANCA</td><td>PFIZER</td><td>MUNICIPIO DE GUARUJA</td><td>2º Reforço</td></tr><tr><td>47</td><td>BRASILIA</td><td>2023-01-17</td><td>Faixa Etária</td><td>DF</td><td>F</td><td>SEM INFORMACAO</td><td>ASTRAZENECA/FIOCRUZ</td><td>UNIDADE BASICA DE SAUDE N 02 DO RECANTO DAS EMAS</td><td>2º Reforço</td></tr><tr><td>69</td><td>CRUZEIRO</td><td>2023-01-06</td><td>Faixa Etária</td><td>SP</td><td>M</td><td>BRANCA</td><td>PFIZER</td><td>PREFEITURA MUNICIPAL DE CRUZEIRO</td><td>2º Reforço</td></tr><tr><td>27</td><td>BARRA DO CHOCA</td><td>2022-03-09</td><td>Faixa Etária</td><td>BA</td><td>F</td><td>PARDA</td><td>PFIZER</td><td>PREFEITURA MUNICIPAL DE BARRA DO CHOCA</td><td>2ª Dose</td></tr><tr><td>57</td><td>CAMPO FORMOSO</td><td>2021-08-24</td><td>Faixa Etária</td><td>BA</td><td>M</td><td>AMARELA</td><td>ASTRAZENECA/FIO ...

# %%
Df_Dim_EstadoEstabelecimento = df_spark_TotalmenteTratado.select('UFdoEstabelecimento').dropDuplicates()

Df_Dim_Cor = df_spark_TotalmenteTratado.select('Cor').dropDuplicates()

Df_Dim_FabricanteVacina = df_spark_TotalmenteTratado.select('FabricanteVacina').dropDuplicates()

#display(Df_Dim_EstadoEstabelecimento)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
menor_diaCollect = df_spark_TotalmenteTratado.select(min('DataAplicacao')).collect()
maior_diaCollect = df_spark_TotalmenteTratado.select(max('DataAplicacao')).collect()

for diaMENOR in menor_diaCollect:
    menor_dia=diaMENOR[0]
    
for diaMAIOR in maior_diaCollect:
    maior_dia=diaMAIOR[0]
    
#print(menor_dia)
#print(maior_dia)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import explode, sequence, to_date

beginDate = menor_dia
endDate = maior_dia

calendario = spark.sql(f"select explode(sequence(to_date('{beginDate}'), to_date('{endDate}'), interval 1 day)) as Datas")


calendario.createOrReplaceTempView('DimCalendario')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
DimCalendarioAjustado = spark.sql("""


select 
Datas
,Date_format(Datas, 'dd') as Dias
,dayofweek(datas) as DiaSemana
,CASE 
		WHEN dayofweek(datas) = 1 THEN 'Domingo'
		WHEN dayofweek(datas) = 2 THEN 'Segunda-Feira'
		WHEN dayofweek(datas) = 3 THEN 'Terça-Feira'
		WHEN dayofweek(datas) = 4 THEN 'Quarta-Feira'
		WHEN dayofweek(datas) = 5 THEN 'Quinta-Feira'
		WHEN dayofweek(datas) = 6 THEN 'Sexta-Feira'
		WHEN dayofweek(datas) = 7 THEN 'Sábado'
END AS DiaSemanaTxt

,Date_format(Datas, 'MM') as Mes
,cASE
WHEN Date_format(Datas, 'MMMM') = 'January' THEN 'Janeiro'
WHEN Date_format(Datas, 'MMMM') = 'February' THEN 'Fevereiro'
WHEN Date_format(Datas, 'MMMM') = 'March' THEN 'Março'
WHEN Date_format(Datas, 'MMMM') = 'April' THEN 'Abril'
WHEN Date_format(Datas, 'MMMM') = 'May' THEN 'Maio'
WHEN Date_format(Datas, 'MMMM') = 'June' THEN 'Junho'
WHEN Date_format(Datas, 'MMMM') = 'July' THEN 'Julho'
WHEN Date_format(Datas, 'MMMM') = 'August' THEN 'Agosto'
WHEN Date_format(Datas, 'MMMM') = 'September' THEN 'Setembro'
WHEN Date_format(Datas, 'MMMM') = 'October' THEN 'Outubro'
WHEN Date_format(Datas, 'MMMM') = 'November' THEN 'Novembro'
WHEN Date_format(Datas, 'MMMM') = 'December' THEN 'Dezembro'
END as MesText

,year(Datas) as Ano
,weekofyear(Datas) AS SemanaAno

from DimCalendario

Order by Datas asc
 
""")
 

#display(DimCalendarioAjustado)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1934358988027383&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> DimCalendarioAjustado = spark.sql(&#34;&#34;&#34;
# </span><span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> select
# <span class="ansi-green-intense-fg ansi-bold">      5</span> Datas
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/session.py</span> in <span class="ansi-cyan-fg">sql</span><span class="ansi-blue-fg">(self, sqlQuery)</span>
# <span class="ansi-green-intense-fg ansi-bold">    775</span>         <span class="ansi-blue-fg">[</span>Row<span class="ansi-blue-fg">(</span>f1<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">,</span> f2<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;row1&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> Row<span class="ansi-blue-fg">(</span>f1<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">,</span> f2<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;row2&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> Row<span class="ansi-blue-fg">(</span>f1<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">3</span><span class="ansi-blue-fg">,</span> f2<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;row3&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">    776</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 777</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> DataFrame<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>_jsparkSession<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">(</span>sqlQuery<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> self<span class="ansi-blue-fg">.</span>_wrapped<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    778</span>
# <span class="ansi-green-intense-fg ansi-bold">    779</span>     <span class="ansi-green-fg">def</span> table<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> tableName<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: Table or view not found: DimCalendario; line 37 pos 5;
# &#39;Sort [&#39;Datas ASC NULLS FIRST], true
# +- &#39;Project [&#39;Datas, &#39;Date_format(&#39;Datas, dd) AS Dias#135, &#39;dayofweek(&#39;datas) AS DiaSemana#136, CASE WHEN (&#39;dayofweek(&#39;datas) = 1) THEN Domingo WHEN (&#39;dayofweek(&#39;datas) = 2) THEN Segunda-Feira WHEN (&#39;dayofweek(&#39;datas) = 3) THEN Terça-Feira WHEN (&#39;dayofweek(&#39;datas) = 4) THEN Quarta-Feira WHEN (&#39;dayofweek(&#39;datas) = 5) THEN Quinta-Feira WHEN (&#39;dayofweek(&#39;datas) = 6) THEN Sexta-Feira WHEN (&#39;dayofweek(&#39;datas) = 7) THEN Sábado END AS DiaSemanaTxt#137, &#39;Date_format(&#39;Datas, MM) AS Mes#138, CASE WHEN (&#39;Date_format(&#39;Datas, MMMM) = January) THEN Janeiro WHEN (&#39;Date_format(&#39;Datas, MMMM) = February) THEN Fevereiro WHEN (&#39;Date_format(&#39;Datas, MMMM) = March) THEN Março WHEN (&#39;Date_format(&#39;Datas, MMMM) = April) THEN Abril WHEN (&#39;Date_format(&#39;Datas, MMMM) = May) THEN Maio WHEN (&#39;Date_format(&#39;Datas, MMMM) = June) THEN Junho WHEN (&#39;Date_format(&#39;Datas, MMMM) = July) THEN Julho WHEN (&#39;Date_format(&#39;Datas, MMMM) = August) THEN Agosto WHEN (&#39;Date_format(&#39;Datas, MMMM) = September) THEN Setembro WHEN (&#39;Date_format(&#39;Datas, MMMM) = October) THEN Outubro WHEN (&#39;Date_format(&#39;Datas, MMMM) = November) THEN Novembro WHEN (&#39;Date_format(&#39;Datas, MMMM) = December) THEN Dezembro END AS MesText#139, &#39;year(&#39;Datas) AS Ano#140, &#39;weekofyear(&#39;Datas) AS SemanaAno#141]
#    +- &#39;UnresolvedRelation [DimCalendario], [], false
# </div>

# %%
Fato_DfVacinas = df_spark_TotalmenteTratado.\
    withColumn('Mes_Ano', date_format(df_spark_TotalmenteTratado['DataAplicacao'],'MM-yyyy'))
#display(Fato_DfVacinas)

# salva as informações no datalake
spark.conf.set('spark.sql.sources.partitionOverwriteMode', 'dynamic')

Fato_DfVacinas\
    .write.mode('overwrite')\
    .format('parquet')\
    .partitionBy('Mes_Ano')\
    .save('/mnt/consumezone/THIAGO_TESTE/Stack/Fato_DfVacinas')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# aqui salvando as tabelas DIM no Datalake sem particionamento

Df_Dim_EstadoEstabelecimento\
    .write.mode('overwrite')\
    .format('parquet')\
    .save('/mnt/consumezone/THIAGO_TESTE/Stack/Df_Dim_EstadoEstabelecimento')

Df_Dim_Cor\
    .write.mode('overwrite')\
    .format('parquet')\
    .save('/mnt/consumezone/THIAGO_TESTE/Stack/Df_Dim_Cor')

Df_Dim_FabricanteVacina\
    .write.mode('overwrite')\
    .format('parquet')\
    .save('/mnt/consumezone/THIAGO_TESTE/Stack/Df_Dim_FabricanteVacina')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
DimCalendarioAjustado\
    .write.mode('overwrite')\
    .format('parquet')\
    .save('/mnt/consumezone/THIAGO_TESTE/Stack/DimCalendarioAjustado')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3812901243767679&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>DimCalendarioAjustado<span class="ansi-red-fg">\</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>     <span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>mode<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;overwrite&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-red-fg">\</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>     <span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;parquet&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-red-fg">\</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>     <span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;/mnt/consumezone/THIAGO_TESTE/Stack/DimCalendarioAjustado&#39;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;DimCalendarioAjustado&#39; is not defined</div>
