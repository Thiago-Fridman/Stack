# %%
import json
import requests
#from requests.auth import HTTPBasicAuth
import pandas as pd
from pymongo import MongoClient
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
url='https://imunizacao-es.saude.gov.br/_search?scroll=1m'
data = json.dumps({'size':10000})
cabecalho ={
  'Authorization': 'Basic aW11bml6YWNhb19wdWJsaWM6cWx0bzV0JjdyX0ArI1Rsc3RpZ2k=',
  'Content-Type': 'application/json'
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
requisicao_site = requests.request('POST',url,headers=cabecalho,data=data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dados_extraidos =requisicao_site.json()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
LandingZoneDados = pd.json_normalize(dados_extraidos['hits']['hits'])

LandingZoneDados = spark.createDataFrame(LandingZoneDados)
LandingZoneDados.write.mode('overwrite').save('/mnt/landingzone/THIAGO_TESTE_Synapse/Stack', format='json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pandas = pd.json_normalize(dados_extraidos['hits']['hits'])
df_pandas_10Colunas = df_pandas[['_source.paciente_idade','_source.estabelecimento_municipio_nome','_source.vacina_dataAplicacao','_source.vacina_categoria_nome','_source.estabelecimento_uf','_source.paciente_enumSexoBiologico','_source.paciente_racaCor_valor','_source.vacina_fabricante_nome','_source.estabelecimento_razaoSocial','_source.vacina_descricao_dose']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dicionarioFiltrado =df_pandas_10Colunas.to_dict(orient= 'list')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#client = MongoClient("localhost",27017)
client = MongoClient('mongodb+srv://ThiagoAdmin:01111981@clusterthiago.ufo1cua.mongodb.net/test')



print(client.list_database_names())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;Stack_teste&#39;, &#39;admin&#39;, &#39;local&#39;]
# </div>

# %%
BancoStack_teste = client.Stack_teste
BancoStack_teste_ColecaoVacinas_Covid = BancoStack_teste.Vacinas_Covid
#BancoStack_teste.Vacinas_Covid.delete_many( {} )
list(BancoStack_teste.Vacinas_Covid.find())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [{&#39;_id&#39;: ObjectId(&#39;63c5ced0e83ed46261269796&#39;),
#   &#39;_source.paciente_idade&#39;: [49,
#    54,
#    24,
#    19,
#    18,
#    30,
#    11,
#    6,
#    18,
#    14,
#    39,
#    15,
#    39,
#    32,
#    53,
#    8,
#    11,
#    35,
#    48,
#    13,
#    33,
#    16,
#    14,
#    15,
#    37,
#    27,
#    55,
#    28,
#    31,
#    18,
#    29,
#    25,
#    7,
#    45,
#    7,
#    30,
#    17,
#    15,
#    8,
#    39,
#    18,
#    34,
#    31,
#    19,
#    39,
#    47,
#    42,
#    10,
#    32,
#    57,
#    44,
#    36,
#    16,
#    17,
#    12,
#    46,
#    22,
#    35,
#    13,
#    6,
# ...

# %%
BancoStack_teste.Vacinas_Covid.delete_many( {} )
list(BancoStack_teste.Vacinas_Covid.find())
BancoStack_teste_ColecaoVacinas_Covid.insert_one(dicionarioFiltrado)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: &lt;pymongo.results.InsertOneResult at 0x7ff636914280&gt;</div>

# %%
list(BancoStack_teste.Vacinas_Covid.find())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: [{&#39;_id&#39;: ObjectId(&#39;63c727f5f3e91505260ab592&#39;),
#   &#39;_source.paciente_idade&#39;: [57,
#    41,
#    4,
#    20,
#    53,
#    4,
#    72,
#    34,
#    46,
#    23,
#    62,
#    36,
#    31,
#    59,
#    37,
#    25,
#    47,
#    25,
#    18,
#    41,
#    32,
#    32,
#    44,
#    39,
#    46,
#    21,
#    41,
#    31,
#    36,
#    34,
#    83,
#    44,
#    17,
#    33,
#    40,
#    18,
#    45,
#    19,
#    64,
#    40,
#    58,
#    41,
#    74,
#    70,
#    30,
#    26,
#    18,
#    3,
#    38,
#    21,
#    46,
#    37,
#    23,
#    38,
#    59,
#    19,
#    69,
#    43,
#    56,
# ...
