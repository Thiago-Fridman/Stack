# %%
import json
import requests
from datetime import date
import pandas as pd
from pymongo import MongoClient
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#dbutils.widgets.text("TODAY",'18-01-2023')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
TODAY=dbutils.widgets.get('TODAY')
TODAY
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: &#39;18-01-2023&#39;</div>

# %%
url='https://imunizacao-es.saude.gov.br/_search?scroll=1m'
data = json.dumps({'size':10000})
cabecalho ={
  'Authorization': 'Basic aW11bml6YWNhb19wdWJsaWM6cWx0bzV0JjdyX0ArI1Rsc3RpZ2k=',
  'Content-Type': 'application/json'
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
requisicao_site = requests.request('POST',url,headers=cabecalho,data=data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dados_extraidos =requisicao_site.json()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Setando as variaveis

# %%
CaminhoLandinzone = f'/mnt/landingzone/THIAGO_TESTE_Synapse/Stack/{TODAY}'

print(CaminhoLandinzone )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/landingzone//mnt/landingzone/THIAGO_TESTE_Synapse/Stack/18-01-2023
# </div>

# %%
#DataProcessamento = date.today().strftime('%d-%m-%Y')


LandingZoneDados = pd.json_normalize(dados_extraidos['hits']['hits'])

LandingZoneDados = spark.createDataFrame(LandingZoneDados)
#LandingZoneDados.write.mode('overwrite').save('/mnt/landingzone/THIAGO_TESTE_Synapse/Stack', format='json')
#LandingZoneDados.write.mode('overwrite').save('/mnt/landingzone/THIAGO_TESTE_Synapse/Stack/'+DataProcessamento, format='json')


LandingZoneDados.write.mode('overwrite').save(CaminhoLandinzone, format='json')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pandas = pd.json_normalize(dados_extraidos['hits']['hits'])
df_pandas_10Colunas = df_pandas[['_source.paciente_idade','_source.estabelecimento_municipio_nome','_source.vacina_dataAplicacao','_source.vacina_categoria_nome','_source.estabelecimento_uf','_source.paciente_enumSexoBiologico','_source.paciente_racaCor_valor','_source.vacina_fabricante_nome','_source.estabelecimento_razaoSocial','_source.vacina_descricao_dose']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dicionarioFiltrado =df_pandas_10Colunas.to_dict(orient= 'list')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#client = MongoClient("localhost",27017)
client = MongoClient('mongodb+srv://ThiagoAdmin:01111981@clusterthiago.ufo1cua.mongodb.net/test')



print(client.list_database_names())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;Stack_teste&#39;, &#39;admin&#39;, &#39;local&#39;]
# </div>

# %%
BancoStack_teste = client.Stack_teste
BancoStack_teste_ColecaoVacinas_Covid = BancoStack_teste.Vacinas_Covid
#BancoStack_teste.Vacinas_Covid.delete_many( {} )
list(BancoStack_teste.Vacinas_Covid.find())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [{&#39;_id&#39;: ObjectId(&#39;63c742145aee123c0f26bf9e&#39;),
#   &#39;_source.paciente_idade&#39;: [38,
#    43,
#    59,
#    49,
#    43,
#    46,
#    29,
#    23,
#    29,
#    19,
#    56,
#    14,
#    42,
#    50,
#    30,
#    54,
#    3,
#    3,
#    3,
#    46,
#    4,
#    3,
#    41,
#    11,
#    45,
#    29,
#    28,
#    70,
#    52,
#    43,
#    29,
#    28,
#    46,
#    28,
#    33,
#    28,
#    12,
#    33,
#    10,
#    56,
#    27,
#    3,
#    57,
#    37,
#    49,
#    55,
#    19,
#    3,
#    3,
#    30,
#    29,
#    50,
#    40,
#    37,
#    20,
#    50,
#    32,
#    20,
#    28,
#    33,
#    33,
#    31,
#    41,
#    12,
#    10,
#    47,
#    6,
#    36,
#    55,
#    35,
#    45,
#    29,
#    4,
#    72,
#    36,
#    34,
#    3,
#    4,
#    23,
#    31,
#    25,
#    37,
#    20,
#    46,
#    62,
#    39,
#    53,
#    34,
#    59,
#    37,
#    47,
#    25,
#    18,
#    41,
#    44,
#    46,
#    32,
#    32,
#    39,
#    21,
#    41,
#    31,
#    36,
#    34,
#    44,
#    17,
#    33,
#    40,
#    45,
#    83,
#    18,
#    19,
#    64,
#    40,
#    58,
#    41,
#    70,
#    30,
#    74,
#    26,
#    38,
#    21,
#    18,
#    3,
#    46,
#    37,
#    23,
#    69,
#    67,
#    27,
#    40,
#    8,
#    56,
#    42,
#    27,
#    13,
#    50,
#    18,
#    12,
#    19,
#    39,
#    43,
#    16,
#    22,
#    16,
#    13,
#    15,
#    30,
#    14,
#    7,
#    13,
#    27,
#    23,
#    23,
#    27,
#    39,
#    25,
#    11,
#    50,
#    22,
#    15,
#    64,
#    20,
#    10,
#    12,
#    18,
#    20,
#    5,
#    21,
#    8,
#    21,
#    10,
#    25,
#    14,
#    41,
#    54,
#    57,
#    52,
#    10,
#    4,
#    11,
#    59,
#    15,
#    33,
#    52,
#    79,
#    45,
#    43,
#    53,
#    38,
#    31,
#    63,
#    18,
#    30,
#    29,
#    47,
#    10,
#    35,
#    21,
#    9,
#    26,
#    15,
#    38,
#    37,
#    36,
#    57,
#    46,
#    34,
#    63,
#    53,
#    43,
#    72,
#    30,
#    48,
#    59,
#    68,
#    57,
#    69,
#    73,
#    18,
#    43,
#    26,
#    55,
#    30,
#    50,
#    28,
#    65,
#    32,
#    74,
#    45,
#    39,
#    43,
#    31,
#    56,
#    23,
#    21,
#    37,
#    31,
#    21,
#    28,
#    25,
#    27,
#    47,
#    41,
#    61,
#    40,
#    33,
#    34,
#    41,
#    31,
#    20,
#    71,
#    82,
#    90,
#    60,
#    41,
#    43,
#    40,
#    57,
#    47,
#    71,
#    34,
#    52,
#    40,
#    61,
#    41,
#    87,
#    89,
#    43,
#    47,
#    65,
#    31,
#    95,
#    48,
#    18,
#    29,
#    23,
#    42,
#    53,
#    38,
#    75,
#    56,
#    16,
#    41,
#    35,
#    61,
#    9,
#    15,
#    18,
#    25,
#    14,
#    33,
#    40,
#    38,
#    16,
#    15,
#    7,
#    20,
#    8,
#    37,
#    48,
#    55,
#    13,
#    16,
#    14,
#    13,
#    13,
#    21,
#    30,
#    33,
#    48,
#    19,
#    28,
#    39,
#    18,
#    28,
#    25,
#    55,
#    47,
#    43,
#    50,
#    52,
#    58,
#    35,
#    20,
#    28,
#    24,
#    59,
#    54,
#    46,
#    26,
#    21,
#    68,
#    22,
#    29,
#    31,
#    64,
#    43,
#    37,
#    72,
#    25,
#    39,
#    42,
#    69,
#    32,
#    48,
#    62,
#    47,
#    39,
#    18,
#    85,
#    44,
#    25,
#    58,
#    30,
#    37,
#    50,
#    54,
#    47,
#    42,
#    39,
#    14,
#    5,
#    4,
#    3,
#    12,
#    30,
#    4,
#    3,
#    7,
#    4,
#    3,
#    11,
#    4,
#    19,
#    5,
#    3,
#    3,
#    7,
#    5,
#    17,
#    6,
#    4,
#    5,
#    13,
#    48,
#    41,
#    28,
#    27,
#    42,
#    23,
#    37,
#    5,
#    8,
#    5,
#    5,
#    6,
#    25,
#    3,
#    11,
#    11,
#    39,
#    6,
#    3,
#    4,
#    10,
#    39,
#    10,
#    9,
#    11,
#    26,
#    17,
#    9,
#    10,
#    19,
#    20,
#    42,
#    3,
#    13,
#    4,
#    4,
#    9,
#    28,
#    3,
#    48,
#    5,
#    17,
#    50,
#    51,
#    56,
#    69,
#    93,
#    52,
#    59,
#    22,
#    54,
#    43,
#    50,
#    3,
#    30,
#    18,
#    31,
#    5,
#    7,
#    49,
#    5,
#    39,
#    41,
#    67,
#    3,
#    27,
#    55,
#    40,
#    50,
#    15,
#    39,
#    9,
#    11,
#    3,
#    5,
#    4,
#    4,
#    35,
#    11,
#    9,
#    14,
#    16,
#    45,
#    3,
#    47,
#    3,
#    5,
#    6,
#    40,
#    22,
#    9,
#    34,
#    7,
#    36,
#    16,
#    49,
#    48,
#    12,
#    5,
#    9,
#    18,
#    51,
#    27,
#    42,
#    40,
#    28,
#    29,
#    21,
#    54,
#    79,
#    46,
#    45,
#    49,
#    18,
#    50,
#    35,
#    47,
#    50,
#    22,
#    66,
#    35,
#    50,
#    32,
#    29,
#    48,
#    25,
#    34,
#    39,
#    32,
#    56,
#    29,
#    5,
#    37,
#    21,
#    24,
#    21,
#    6,
#    53,
#    15,
#    16,
#    11,
#    38,
#    56,
#    44,
#    37,
#    12,
#    47,
#    39,
#    54,
#    43,
#    40,
#    18,
#    9,
#    18,
#    70,
#    34,
#    37,
#    22,
#    62,
#    17,
#    6,
#    57,
#    9,
#    52,
#    31,
#    11,
#    13,
#    42,
#    7,
#    21,
#    35,
#    10,
#    27,
#    15,
#    42,
#    18,
#    10,
#    13,
#    28,
#    12,
#    46,
#    14,
#    34,
#    8,
#    16,
#    40,
#    23,
#    18,
#    35,
#    5,
#    63,
#    70,
#    25,
#    23,
#    19,
#    16,
#    35,
#    8,
#    25,
#    24,
#    23,
#    23,
#    9,
#    53,
#    27,
#    21,
#    6,
#    39,
#    13,
#    4,
#    9,
#    4,
#    25,
#    4,
#    57,
#    7,
#    4,
#    5,
#    54,
#    3,
#    59,
#    3,
#    5,
#    8,
#    21,
#    16,
#    4,
#    5,
#    38,
#    9,
#    3,
#    13,
#    11,
#    5,
#    4,
#    36,
#    45,
#    5,
#    5,
#    13,
#    6,
#    5,
#    4,
#    3,
#    5,
#    3,
#    5,
#    12,
#    9,
#    5,
#    5,
#    24,
#    32,
#    5,
#    5,
#    4,
#    5,
#    32,
#    41,
#    16,
#    43,
#    20,
#    19,
#    25,
#    6,
#    58,
#    12,
#    17,
#    5,
#    36,
#    38,
#    24,
#    47,
#    39,
#    11,
#    12,
#    11,
#    15,
#    24,
#    11,
#    52,
#    35,
#    25,
#    43,
#    28,
#    95,
#    47,
#    20,
#    19,
#    63,
#    50,
#    24,
#    77,
#    46,
#    31,
#    12,
#    7,
#    45,
#    27,
#    28,
#    45,
#    10,
#    39,
#    46,
#    37,
#    34,
#    17,
#    8,
#    15,
#    22,
#    15,
#    7,
#    18,
#    18,
#    30,
#    54,
#    15,
#    20,
#    32,
#    27,
#    41,
#    10,
#    5,
#    14,
#    14,
#    5,
#    3,
#    25,
#    3,
#    22,
#    25,
#    15,
#    16,
#    12,
#    39,
#    4,
#    64,
#    6,
#    11,
#    37,
#    5,
#    6,
#    3,
#    23,
#    40,
#    4,
#    28,
#    13,
#    7,
#    15,
#    21,
#    28,
#    3,
#    9,
#    24,
#    26,
#    7,
#    13,
#    23,
#    4,
#    29,
#    7,
#    5,
#    9,
#    22,
#    34,
#    5,
#    30,
#    48,
#    14,
#    64,
#    22,
#    58,
#    50,
#    20,
#    18,
#    50,
#    47,
#    42,
#    22,
#    11,
#    12,
#    54,
#    33,
#    12,
#    53,
#    38,
#    20,
#    58,
#    45,
#    8,
#    29,
#    53,
#    18,
#    44,
#    28,
#    16,
#    23,
#    40,
#    10,
#    20,
#    15,
#    12,
#    48,
#    13,
#    51,
#    56,
#    10,
#    56,
#    44,
#    30,
#    48,
#    23,
#    80,
#    31,
#    77,
#    24,
#    31,
#    40,
#    60,
#    35,
#    41,
#    68,
#    33,
#    35,
#    28,
#    69,
#    24,
#    40,
#    40,
#    28,
#    34,
#    67,
#    38,
#    40,
#    63,
#    39,
#    28,
#    41,
#    52,
#    24,
#    46,
#    49,
#    50,
#    36,
#    43,
#    35,
#    18,
#    40,
#    35,
#    29,
#    64,
#    51,
#    44,
#    42,
#    18,
#    24,
#    38,
#    44,
#    27,
#    70,
#    71,
#    41,
#    66,
#    49,
#    79,
#    77,
#    24,
#    64,
#    17,
#    71,
#    66,
#    80,
#    52,
#    81,
#    53,
#    53,
#    74,
#    39,
#    80,
#    29,
#    53,
#    48,
#    46,
#    37,
#    44,
#    30,
#    36,
#    29,
#    41,
#    39,
#    25,
#    40,
#    58,
#    74,
#    36,
#    58,
#    32,
#    45,
#    68,
#    41,
#    60,
#    35,
#    52,
#    12,
#    22,
#    70,
#    34,
#    8,
#    32,
#    49,
#    32,
#    21,
#    14,
#    34,
#    45,
#    56,
#    40,
#    65,
#    49,
#    53,
#    40,
#    23,
#    42,
#    50,
#    45,
#    22,
#    34,
#    19,
#    26,
#    22,
#    26,
#    48,
#    41,
#    27,
#    25,
#    43,
#    78,
#    51,
#    19,
#    41,
#    27,
#    43,
#    33,
#    51,
#    24,
#    18,
#    47,
#    67,
#    28,
#    58,
#    43,
#    41,
#    65,
#    20,
#    76,
#    52,
#    63,
#    26,
#    27,
#    55,
#    56,
#    44,
#    25,
#    90,
#    23,
#    19,
#    42,
#    63,
#    34,
#    22,
#    67,
#    33,
#    57,
#    24,
#    32,
#    25,
#    30,
#    22,
#    29,
#    38,
#    29,
#    34,
#    45,
#    30,
#    31,
#    39,
#    24,
#    44,
#    28,
#    21,
#    54,
#    40,
#    39,
#    29,
#    30,
#    36,
#    15,
#    8,
#    21,
#    16,
#    12,
#    71,
#    36,
#    22,
#    24,
#    17,
#    39,
#    29,
#    6,
#    52,
#    12,
#    44,
#    84,
#    30,
#    ...],
#   &#39;_source.estabelecimento_municipio_nome&#39;: [&#39;SOROCABA&#39;,
#    &#39;PIRACICABA&#39;,
#    &#39;FRANCO DA ROCHA&#39;,
#    &#39;SAO PAULO&#39;,
#    &#39;TABOAO DA SERRA&#39;,
#    &#39;FRANCISCO MORATO&#39;,
#    &#39;TABOAO DA SERRA&#39;,
#    &#39;SAO JOSE DO RIO PRETO&#39;,
#    &#39;SAO PAULO&#39;,
#    &#39;ITACOATIARA&#39;,
#    &#39;CAUCAIA&#39;,
#    &#39;ITAPURANGA&#39;,
#    &#39;SAO JOSE DOS PINHAIS&#39;,
#    &#39;VALENCA&#39;,
#    &#39;MINEIROS&#39;,
#    &#39;ALMEIRIM&#39;,
#    &#39;ITAPETIM&#39;,
#    &#39;RIO DE JANEIRO&#39;,
#    &#39;PINDAMONHANGABA&#39;,
#    &#39;CRATO&#39;,
#    &#39;TEODORO SAMPAIO&#39;,
#    &#39;SAO PAULO&#39;,
#    &#39;BARRINHA&#39;,
#    &#39;OSASCO&#39;,
#    &#39;MORRO AGUDO&#39;,

# %%
BancoStack_teste.Vacinas_Covid.delete_many( {} )
list(BancoStack_teste.Vacinas_Covid.find())
BancoStack_teste_ColecaoVacinas_Covid.insert_one(dicionarioFiltrado)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: &lt;pymongo.results.InsertOneResult at 0x7f68cd5ae9a0&gt;</div>

# %%
list(BancoStack_teste.Vacinas_Covid.find())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: [{&#39;_id&#39;: ObjectId(&#39;63c7ccfa9db2e2a3febd22bc&#39;),
#   &#39;_source.paciente_idade&#39;: [57,
#    17,
#    19,
#    15,
#    63,
#    39,
#    25,
#    48,
#    42,
#    28,
#    15,
#    39,
#    9,
#    11,
#    3,
#    5,
#    4,
#    4,
#    35,
#    11,
#    9,
#    14,
#    16,
#    45,
#    3,
#    47,
#    3,
#    5,
#    6,
#    40,
#    22,
#    9,
#    34,
#    7,
#    36,
#    16,
#    49,
#    48,
#    12,
#    5,
#    9,
#    18,
#    51,
#    27,
#    42,
#    40,
#    28,
#    29,
#    21,
#    54,
#    79,
#    46,
#    45,
#    49,
#    18,
#    50,
#    35,
#    47,
#    50,
#    22,
#    66,
#    35,
#    50,
#    32,
#    29,
#    48,
#    25,
#    34,
#    39,
#    32,
#    56,
#    29,
#    5,
#    37,
#    21,
#    24,
#    21,
#    6,
#    53,
#    15,
#    16,
#    11,
#    38,
#    56,
#    44,
#    37,
#    12,
#    47,
#    39,
#    54,
#    43,
#    40,
#    18,
#    9,
#    18,
#    70,
#    34,
#    37,
#    22,
#    62,
#    17,
#    6,
#    57,
#    9,
#    52,
#    31,
#    11,
#    13,
#    42,
#    7,
#    21,
#    35,
#    10,
#    27,
#    15,
#    42,
#    18,
#    10,
#    13,
#    28,
#    12,
#    46,
#    14,
#    34,
#    8,
#    16,
#    40,
#    23,
#    18,
#    35,
#    5,
#    63,
#    70,
#    25,
#    23,
#    19,
#    16,
#    35,
#    8,
#    25,
#    24,
#    23,
#    23,
#    9,
#    53,
#    27,
#    21,
#    6,
#    39,
#    13,
#    4,
#    9,
#    4,
#    25,
#    4,
#    57,
#    7,
#    4,
#    5,
#    54,
#    3,
#    59,
#    3,
#    5,
#    8,
#    21,
#    16,
#    4,
#    5,
#    38,
#    9,
#    3,
#    13,
#    11,
#    5,
#    4,
#    36,
#    45,
#    5,
#    5,
#    13,
#    6,
#    5,
#    4,
#    3,
#    5,
#    3,
#    5,
#    12,
#    9,
#    5,
#    5,
#    24,
#    32,
#    5,
#    5,
#    4,
#    5,
#    32,
#    41,
#    16,
#    43,
#    20,
#    19,
#    25,
#    6,
#    58,
#    12,
#    17,
#    5,
#    36,
#    38,
#    24,
#    47,
#    39,
#    11,
#    12,
#    11,
#    15,
#    24,
#    11,
#    52,
#    35,
#    25,
#    43,
#    28,
#    95,
#    47,
#    20,
#    19,
#    63,
#    50,
#    24,
#    77,
#    46,
#    31,
#    12,
#    7,
#    45,
#    27,
#    28,
#    45,
#    10,
#    39,
#    46,
#    37,
#    34,
#    17,
#    8,
#    15,
#    22,
#    15,
#    7,
#    18,
#    18,
#    30,
#    54,
#    15,
#    20,
#    32,
#    27,
#    41,
#    10,
#    5,
#    14,
#    14,
#    5,
#    3,
#    25,
#    3,
#    22,
#    25,
#    15,
#    16,
#    12,
#    39,
#    4,
#    64,
#    6,
#    11,
#    37,
#    5,
#    6,
#    3,
#    23,
#    40,
#    4,
#    28,
#    13,
#    7,
#    15,
#    21,
#    28,
#    3,
#    9,
#    24,
#    26,
#    7,
#    13,
#    23,
#    4,
#    29,
#    7,
#    5,
#    9,
#    22,
#    34,
#    5,
#    30,
#    48,
#    14,
#    64,
#    22,
#    58,
#    20,
#    18,
#    50,
#    47,
#    42,
#    22,
#    11,
#    12,
#    54,
#    33,
#    12,
#    53,
#    38,
#    20,
#    58,
#    45,
#    8,
#    29,
#    53,
#    18,
#    44,
#    28,
#    16,
#    23,
#    40,
#    10,
#    20,
#    15,
#    12,
#    48,
#    13,
#    51,
#    56,
#    10,
#    56,
#    44,
#    30,
#    48,
#    23,
#    80,
#    31,
#    77,
#    24,
#    31,
#    40,
#    60,
#    35,
#    41,
#    68,
#    33,
#    35,
#    28,
#    69,
#    24,
#    40,
#    40,
#    28,
#    34,
#    67,
#    38,
#    40,
#    63,
#    39,
#    28,
#    41,
#    52,
#    24,
#    46,
#    49,
#    50,
#    36,
#    43,
#    35,
#    18,
#    40,
#    35,
#    29,
#    64,
#    51,
#    44,
#    42,
#    18,
#    24,
#    38,
#    44,
#    27,
#    70,
#    71,
#    41,
#    66,
#    49,
#    79,
#    77,
#    24,
#    64,
#    17,
#    71,
#    66,
#    80,
#    52,
#    81,
#    53,
#    53,
#    74,
#    39,
#    80,
#    29,
#    53,
#    48,
#    46,
#    37,
#    44,
#    30,
#    36,
#    29,
#    41,
#    39,
#    25,
#    40,
#    58,
#    74,
#    36,
#    58,
#    32,
#    45,
#    68,
#    41,
#    60,
#    35,
#    52,
#    12,
#    22,
#    70,
#    34,
#    8,
#    32,
#    49,
#    32,
#    21,
#    14,
#    34,
#    45,
#    56,
#    40,
#    65,
#    49,
#    53,
#    40,
#    23,
#    42,
#    50,
#    45,
#    22,
#    34,
#    19,
#    26,
#    22,
#    26,
#    48,
#    41,
#    27,
#    25,
#    43,
#    78,
#    51,
#    19,
#    41,
#    27,
#    43,
#    33,
#    51,
#    24,
#    18,
#    47,
#    67,
#    28,
#    58,
#    43,
#    41,
#    65,
#    20,
#    76,
#    52,
#    63,
#    26,
#    27,
#    55,
#    56,
#    44,
#    25,
#    90,
#    23,
#    19,
#    42,
#    63,
#    34,
#    22,
#    67,
#    33,
#    57,
#    24,
#    32,
#    25,
#    30,
#    22,
#    29,
#    38,
#    29,
#    34,
#    45,
#    30,
#    31,
#    39,
#    24,
#    44,
#    28,
#    21,
#    54,
#    40,
#    39,
#    29,
#    30,
#    36,
#    15,
#    8,
#    21,
#    16,
#    12,
#    71,
#    36,
#    22,
#    24,
#    17,
#    39,
#    29,
#    6,
#    52,
#    12,
#    44,
#    84,
#    30,
#    21,
#    10,
#    42,
#    19,
#    13,
#    25,
#    17,
#    8,
#    42,
#    36,
#    38,
#    44,
#    39,
#    23,
#    30,
#    35,
#    61,
#    42,
#    26,
#    31,
#    68,
#    75,
#    39,
#    45,
#    8,
#    13,
#    45,
#    14,
#    20,
#    58,
#    7,
#    31,
#    16,
#    8,
#    23,
#    61,
#    9,
#    13,
#    10,
#    33,
#    13,
#    15,
#    12,
#    12,
#    66,
#    13,
#    14,
#    9,
#    48,
#    42,
#    46,
#    18,
#    34,
#    62,
#    35,
#    10,
#    38,
#    5,
#    36,
#    44,
#    24,
#    13,
#    57,
#    40,
#    21,
#    30,
#    25,
#    28,
#    14,
#    28,
#    47,
#    20,
#    63,
#    27,
#    8,
#    8,
#    29,
#    47,
#    11,
#    51,
#    13,
#    40,
#    33,
#    28,
#    22,
#    58,
#    39,
#    10,
#    38,
#    33,
#    44,
#    39,
#    46,
#    64,
#    49,
#    26,
#    48,
#    44,
#    18,
#    48,
#    57,
#    68,
#    61,
#    47,
#    54,
#    25,
#    25,
#    67,
#    40,
#    56,
#    58,
#    23,
#    41,
#    33,
#    47,
#    57,
#    67,
#    80,
#    57,
#    53,
#    43,
#    36,
#    57,
#    26,
#    42,
#    74,
#    36,
#    33,
#    49,
#    71,
#    50,
#    61,
#    58,
#    45,
#    32,
#    37,
#    50,
#    34,
#    26,
#    12,
#    23,
#    59,
#    16,
#    19,
#    14,
#    31,
#    49,
#    76,
#    34,
#    52,
#    45,
#    17,
#    17,
#    12,
#    20,
#    28,
#    33,
#    20,
#    13,
#    12,
#    12,
#    14,
#    25,
#    22,
#    19,
#    24,
#    63,
#    21,
#    18,
#    12,
#    54,
#    29,
#    24,
#    7,
#    61,
#    24,
#    53,
#    22,
#    32,
#    42,
#    32,
#    26,
#    57,
#    35,
#    35,
#    33,
#    18,
#    44,
#    35,
#    47,
#    32,
#    40,
#    48,
#    61,
#    27,
#    20,
#    32,
#    42,
#    24,
#    19,
#    69,
#    18,
#    69,
#    36,
#    19,
#    27,
#    14,
#    56,
#    36,
#    14,
#    18,
#    65,
#    58,
#    69,
#    103,
#    54,
#    81,
#    32,
#    78,
#    75,
#    76,
#    69,
#    32,
#    80,
#    60,
#    81,
#    37,
#    15,
#    46,
#    12,
#    45,
#    23,
#    13,
#    14,
#    13,
#    19,
#    42,
#    26,
#    3,
#    41,
#    13,
#    55,
#    81,
#    35,
#    23,
#    24,
#    24,
#    35,
#    39,
#    44,
#    60,
#    29,
#    30,
#    19,
#    56,
#    36,
#    19,
#    50,
#    30,
#    27,
#    46,
#    38,
#    61,
#    36,
#    37,
#    35,
#    20,
#    70,
#    35,
#    47,
#    45,
#    60,
#    47,
#    21,
#    65,
#    72,
#    18,
#    30,
#    53,
#    44,
#    68,
#    79,
#    31,
#    29,
#    46,
#    28,
#    29,
#    12,
#    21,
#    65,
#    62,
#    65,
#    85,
#    75,
#    87,
#    86,
#    84,
#    80,
#    71,
#    41,
#    43,
#    73,
#    77,
#    65,
#    42,
#    48,
#    66,
#    70,
#    47,
#    32,
#    83,
#    29,
#    57,
#    21,
#    66,
#    55,
#    62,
#    47,
#    70,
#    23,
#    14,
#    44,
#    21,
#    49,
#    74,
#    36,
#    69,
#    31,
#    73,
#    65,
#    62,
#    50,
#    34,
#    48,
#    23,
#    61,
#    16,
#    49,
#    56,
#    60,
#    27,
#    39,
#    72,
#    42,
#    60,
#    25,
#    24,
#    66,
#    17,
#    31,
#    17,
#    66,
#    20,
#    58,
#    58,
#    21,
#    48,
#    33,
#    40,
#    78,
#    60,
#    54,
#    49,
#    41,
#    33,
#    19,
#    73,
#    35,
#    31,
#    30,
#    30,
#    40,
#    54,
#    67,
#    42,
#    35,
#    47,
#    54,
#    41,
#    38,
#    42,
#    19,
#    77,
#    22,
#    49,
#    44,
#    30,
#    32,
#    57,
#    46,
#    28,
#    29,
#    38,
#    48,
#    80,
#    25,
#    41,
#    18,
#    40,
#    38,
#    22,
#    24,
#    70,
#    33,
#    28,
#    22,
#    52,
#    30,
#    40,
#    27,
#    68,
#    28,
#    36,
#    33,
#    43,
#    41,
#    41,
#    81,
#    27,
#    42,
#    32,
#    23,
#    33,
#    53,
#    54,
#    90,
#    28,
#    24,
#    25,
#    18,
#    43,
#    21,
#    35,
#    49,
#    31,
#    22,
#    41,
#    54,
#    50,
#    33,
#    20,
#    41,
#    78,
#    48,
#    35,
#    ...],
#   &#39;_source.estabelecimento_municipio_nome&#39;: [&#39;NOVA EUROPA&#39;,
#    &#39;BARBOSA&#39;,
#    &#39;SAO PAULO&#39;,
#    &#39;ANAJAS&#39;,
#    &#39;NATAL&#39;,
#    &#39;SAO JOSE DO RIO PRETO&#39;,
#    &#39;CAMPINAS&#39;,
#    &#39;HORTOLANDIA&#39;,
#    &#39;CAUCAIA&#39;,
#    &#39;SAO PAULO&#39;,
#    &#39;ARACI&#39;,
#    &#39;CARNEIROS&#39;,
#    &#39;CAMARAGIBE&#39;,
#    &#39;PAULO AFONSO&#39;,
#    &#39;SAO CAETANO DO SUL&#39;,
#    &#39;BURITAMA&#39;,
#    &#39;CABO DE SANTO AGOSTINHO&#39;,
#    &#39;SANTANA DE PARNAIBA&#39;,
#    &#39;SAO LUIS&#39;,
#    &#39;SANTOS DUMONT&#39;,
#    &#39;GUAIUBA&#39;,
#    &#39;JACOBINA&#39;,
#    &#39;MULUNGU&#39;,
#    &#39;MEDEIROS
